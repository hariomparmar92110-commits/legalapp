# %%
import pickle
import bz2
sfile1 = bz2.BZ2File('All Model', 'r')
models=pickle.load(sfile1)
sfile2 = bz2.BZ2File('All Vector', 'r')
vectorizer=pickle.load(sfile2)
cas=input("Enter Case Study")
# Out:
# C:\Users\Dhairya Vyas\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Enter Case StudyA person was attacked by an armed assailant in a dark alley. In an act of self-defense, the victim fought back and managed to disarm the attacker. However, during the struggle, the assailant was killed. In this case, it can be argued that the victim acted in self-defense to protect their life, and the homicide may not be classified as murder.

# %%
import pandas as pd
df=pd.DataFrame({"case study":[cas]})
df
# Out:
#                                           case study
# 0  A person was attacked by an armed assailant in...

# %%
import nltk 
def remove_stopwords(text):
    stopwords=nltk.corpus.stopwords.words('english')
    clean_text=' '.join([word for word in text.split() if word not in stopwords])
    return clean_text

from nltk.stem.porter import PorterStemmer
def cleanup_data(df):
    # remove handle
    df['clean'] = df["case study"].str.replace("@", "") 
    # remove links
    df['clean'] = df['clean'].str.replace(r"http\S+", "") 
    # remove punctuations and special characters
    df['clean'] = df['clean'].str.replace("[^a-zA-Z]", " ") 
    # remove stop words
    df['clean'] = df['clean'].apply(lambda text : remove_stopwords(text.lower()))
    # split text and tokenize
    df['clean'] = df['clean'].apply(lambda x: x.split())
    # let's apply stemmer
    stemmer = PorterStemmer()
    df['clean'] = df['clean'].apply(lambda x: [stemmer.stem(i) for i in x])
    # stitch back words
    df['clean'] = df['clean'].apply(lambda x: ' '.join([w for w in x]))
    # remove small words
    df['clean'] = df['clean'].apply(lambda x: ' '.join([w for w in x.split() if len(w)>3]))
cleanup_data(df)
df
# Out:
#                                           case study  \
# 0  A person was attacked by an armed assailant in...
#
#                                                clean
# 0  person attack assail dark alley. self-defense,...

# %%
df["clean"][0]
# Out:
# 'person attack assail dark alley. self-defense, victim fought back manag disarm attacker. however, struggle, assail killed. case, argu victim self-defens protect life, homicid classifi murder.'

# %%
feature=vectorizer.transform([df["clean"][0]])
feature.toarray()
# Out:
# array([[0., 0., 0., ..., 0., 0., 0.]])

# %%
names = ["K-Nearest Neighbors", "Liner SVM",
         "Decision Tree", "Random Forest",
         "ExtraTreesClassifier"]
for i in range(0,len(names)):
    print(names[i])
    print(models[i].predict(feature))
# Out:
# K-Nearest Neighbors
# ['300']
# Liner SVM
# ['300']
# Decision Tree
# ['360']
# Random Forest
# ['300']
# ExtraTreesClassifier
# ['300']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# C:\Users\Dhairya Vyas\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# 1.6.1
